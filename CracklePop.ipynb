# %%
def cp():
    for i in range(1, 101):
        print(i)
        if i%15 == 0:
            print('CracklePop')
        elif i%5 == 0:
            print('Pop')
        elif i%3 == 0:
            print('Crackle')

# %%
cp()
# Out:
# 1
# 2
# 3
# Crackle
# 4
# 5
# Pop
# 6
# Crackle
# 7
# 8
# 9
# Crackle
# 10
# Pop
# 11
# 12
# Crackle
# 13
# 14
# 15
# CracklePop
# 16
# 17
# 18
# Crackle
# 19
# 20
# Pop
# 21
# Crackle
# 22
# 23
# 24
# Crackle
# 25
# Pop
# 26
# 27
# Crackle
# 28
# 29
# 30
# CracklePop
# 31
# 32
# 33
# Crackle
# 34
# 35
# Pop
# 36
# Crackle
# 37
# 38
# 39
# Crackle
# 40
# Pop
# 41
# 42
# Crackle
# 43
# 44
# 45
# CracklePop
# 46
# 47
# 48
# Crackle
# 49
# 50
# Pop
# 51
# Crackle
# 52
# 53
# 54
# Crackle
# 55
# Pop
# 56
# 57
# Crackle
# 58
# 59
# 60
# CracklePop
# 61
# 62
# 63
# Crackle
# 64
# 65
# Pop
# 66
# Crackle
# 67
# 68
# 69
# Crackle
# 70
# Pop
# 71
# 72
# Crackle
# 73
# 74
# 75
# CracklePop
# 76
# 77
# 78
# Crackle
# 79
# 80
# Pop
# 81
# Crackle
# 82
# 83
# 84
# Crackle
# 85
# Pop
# 86
# 87
# Crackle
# 88
# 89
# 90
# CracklePop
# 91
# 92
# 93
# Crackle
# 94
# 95
# Pop
# 96
# Crackle
# 97
# 98
# 99
# Crackle
# 100
# Pop

# %%
board = [0] * 9
board
# Out:
# [0, 0, 0, 0, 0, 0, 0, 0, 0]
